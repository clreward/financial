# %%
import pandas as pd
import numpy as np

# %%
diet = pd.read_csv("dataset.csv")
diet.head()
# Out:
#    Unnamed: 0  age  weight(kg)  height(m) gender        BMI      BMR  \
# 0           1    2   16.097862   0.932025      F  18.531612  958.584
# 1           2    4   14.619374   0.916687      F  17.397496  932.383
# 2           4    4   17.899918   0.997288      F  17.997414  977.578
# 3           6    3   13.532880   1.022786      F  12.936609  944.689
# 4           8    4   17.039484   1.053977      M  15.338909  799.229
#
#    activity_level  calories_to_maintain_weight  BMI_tags  Label
# 0             1.2                    1150.3008         8     13
# 1             1.7                    1585.0511         7      1
# 2             1.9                    1857.3982         7      4
# 3             1.9                    1794.9091         7      3
# 4             1.9                    1518.5351         7      0

# %%
diet.shape
# Out:
# (10726, 11)

# %%
diet.info

# %%
diet.duplicated().sum()
# Out:
# 0

# %%
diet.describe()

# %%
# Identify non-numeric columns
non_numeric_columns = diet.select_dtypes(include=['object']).columns
print("Non-numeric columns:", non_numeric_columns)

# Create a DataFrame with only numeric columns
numeric_diet = diet.select_dtypes(include=['number'])

# Calculate the correlation matrix
corr = numeric_diet.corr()
print(corr)
# Out:
# Non-numeric columns: Index(['gender'], dtype='object')
#                              Unnamed: 0       age  weight(kg)  height(m)  \
# Unnamed: 0                     1.000000  0.923125    0.977221   0.655273
# age                            0.923125  1.000000    0.889685   0.544050
# weight(kg)                     0.977221  0.889685    1.000000   0.769577
# height(m)                      0.655273  0.544050    0.769577   1.000000
# BMI                            0.971348  0.908640    0.952746   0.546076
# BMR                            0.836301  0.686429    0.901031   0.836209
# activity_level                -0.385720 -0.312864   -0.402500  -0.328990
# calories_to_maintain_weight    0.474235  0.394097    0.534520   0.577383
# BMI_tags                       0.868821  0.757336    0.889483   0.598643
# Label                          0.839286  0.724655    0.880967   0.659814
#
#                                   BMI       BMR  activity_level  \
# ...

# %%
import seaborn as sns
sns.heatmap(corr,annot=True,cbar=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# diet['label'].value_counts()

# %%
import matplotlib.pyplot as plt
sns.distplot(diet['age'])
plt.show()
# Out:
# C:\Users\MEMBER COMPUTER TECH\AppData\Local\Temp\ipykernel_3912\4154283140.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(diet['age'])

# %%
import matplotlib.pyplot as plt
sns.distplot(diet['BMI'])
plt.show()
# Out:
# C:\Users\MEMBER COMPUTER TECH\AppData\Local\Temp\ipykernel_3912\2481360990.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(diet['BMI'])

# %%
# print(diet)

# %%
diet['Label'].value_counts()
# Out:
# Label
# 29    941
# 28    843
# 27    841
# 16    834
# 26    760
# 19    760
# 31    649
# 17    577
# 20    527
# 1     508
# 3     429
# 0     421
# 30    392
# 25    333
# 15    327
# 18    316
# 2     280
# 22    230
# 4     184
# 21    123
# 13    115
# 5     112
# 14     96
# 6      67
# 7      39
# 12     22
# Name: count, dtype: int64

# %%
unique_labels = diet['Label'].unique()
print(unique_labels)
# Out:
# [13  1  4  3  0 12  2 14 15 16 17 19  5  6 18  7 20 22 21 29 27 31 30 26
#  28 25]

# %%
# If 'Label' column has integer values
# diet_dict = {int(k.split('diet_list')[-1]): v for k, v in diet_dict.items()}

# %%
# # Print to check if values match
# print(diet['Label'].map(diet_dict))

# %%
import pandas as pd

# Example DataFrame
# data = {'Label': ['diet_list1', 'diet_list2', 'diet_list3', 'diet_list4', 'diet_list5']}
# diet = pd.DataFrame(data)

# Dictionary
diet_dict = {
    'diet_list1': 0,
    'diet_list2': 1,
    'diet_list3': 2,
    'diet_list4': 3,
    'diet_list5': 4,
    'diet_list6': 5,
    'diet_list7': 6,
    'diet_list8': 7,
    'diet_list9': 12,
    'diet_list10': 13,
    'diet_list11': 14,
    'diet_list12': 15,
    'diet_list13': 16,
    'diet_list14': 17,
    'diet_list15': 18,
    'diet_list16': 19,
    'diet_list17': 20,
    'diet_list18': 21,
    'diet_list19': 22,
    'diet_list20': 25,
    'diet_list21': 26,
    'diet_list22': 27,
    'diet_list23': 28,
    'diet_list24': 29,
    'diet_list25': 30,
    'diet_list26': 31
}

# Mapping
diet['diet_list'] = diet['Label'].map(diet_dict)
print(diet['diet_list'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 10721   NaN
# 10722   NaN
# 10723   NaN
# 10724   NaN
# 10725   NaN
# Name: diet_list, Length: 10726, dtype: float64

# %%
# Print to check if values match
print(diet['Label'].map(diet_dict))
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 10721   NaN
# 10722   NaN
# 10723   NaN
# 10724   NaN
# 10725   NaN
# Name: Label, Length: 10726, dtype: float64

# %%
# diet['diet_list'].value_counts()
diet['diet_list'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: diet_list, dtype: float64

# %%
unique_labels = diet['Label'].unique()
print(unique_labels)
# Out:
# [13  1  4  3  0 12  2 14 15 16 17 19  5  6 18  7 20 22 21 29 27 31 30 26
#  28 25]

# %%
diet.drop(['Label'],axis=1,inplace=True)
diet.head()
# Out:
#    Unnamed: 0  age  weight(kg)  height(m) gender        BMI      BMR  \
# 0           1    2   16.097862   0.932025      F  18.531612  958.584
# 1           2    4   14.619374   0.916687      F  17.397496  932.383
# 2           4    4   17.899918   0.997288      F  17.997414  977.578
# 3           6    3   13.532880   1.022786      F  12.936609  944.689
# 4           8    4   17.039484   1.053977      M  15.338909  799.229
#
#    activity_level  calories_to_maintain_weight  BMI_tags  diet_list
# 0             1.2                    1150.3008         8        NaN
# 1             1.7                    1585.0511         7        NaN
# 2             1.9                    1857.3982         7        NaN
# 3             1.9                    1794.9091         7        NaN
# 4             1.9                    1518.5351         7        NaN

# %%
x = diet.drop('BMI',axis=1)
y = diet['BMI']
x.shape
# Out:
# (10726, 10)

# %%
#explore Target Distributio
sns.catplot(x="gender", kind="count", data=diet, palette="Set1")
# Out:
# C:\Users\MEMBER COMPUTER TECH\AppData\Local\Temp\ipykernel_3912\2451095730.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="gender", kind="count", data=diet, palette="Set1")

# %%
#explore Target Distributio
# sns.catplot(x="BMI", kind="count", data=diet, palette="Set1")
